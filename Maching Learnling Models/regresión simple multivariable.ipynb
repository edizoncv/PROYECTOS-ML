# %%
# MI PRIMER MODELO DE ML

# %%
import pandas as pd

# %%
data=pd.read_csv('C:/Users/edizo/OneDrive/Escritorio/MarathonData.csv')

# %%
print(data)
# Out:
#     id  Marathon              Name Category  km4week    sp4week CrossTraining  \
# 0    1  Prague17      Blair MORGAN      MAM    132.8  14.434783           NaN
# 1    2  Prague17     Robert Heczko      MAM     68.6  13.674419           NaN
# 2    3  Prague17     Michon Jerome      MAM     82.7  13.520436           NaN
# 3    4  Prague17     Daniel Or lek      M45    137.5  12.258544           NaN
# 4    5  Prague17      Luk ? Mr zek      MAM     84.6  13.945055           NaN
# ..  ..       ...               ...      ...      ...        ...           ...
# 82  83  Prague17  Stefano Vegliani      M55     50.0  10.830325           NaN
# 83  84  Prague17    Andrej Madliak      M40     33.6  10.130653   ciclista 3h
# 84  85  Prague17        Yoi Ohsako      M40     55.4  11.043189           NaN
# 85  86  Prague17        Simon Dunn      M45     33.2  11.066667           NaN
# 86  87  Prague17       Pavel ?imek      M40     17.9  10.848485   ciclista 5h
#
#    Wall21  MarathonTime CATEGORY
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 87 entries, 0 to 86
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             87 non-null     int64
#  1   Marathon       87 non-null     object
#  2   Name           87 non-null     object
#  3   Category       81 non-null     object
#  4   km4week        87 non-null     float64
#  5   sp4week        87 non-null     float64
#  6   CrossTraining  13 non-null     object
#  7   Wall21         87 non-null     object
#  8   MarathonTime   87 non-null     float64
#  9   CATEGORY       87 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 6.9+ KB

# %%
data['Wall21']=pd.to_numeric(data['Wall21'],errors='coerce')

# %%
data.describe()
# Out:
#               id     km4week       sp4week     Wall21  MarathonTime
# count  87.000000   87.000000     87.000000  81.000000     87.000000
# mean   44.000000   62.347126    139.840706   1.630617      3.319080
# std    25.258662   26.956019   1191.427864   0.210490      0.376923
# min     1.000000   17.900000      8.031414   1.160000      2.370000
# 25%    22.500000   44.200000     11.498168   1.450000      3.045000
# 50%    44.000000   58.800000     12.163424   1.620000      3.320000
# 75%    65.500000   77.500000     12.854036   1.760000      3.605000
# max    87.000000  137.500000  11125.000000   2.050000      3.980000

# %%
data.hist()
# Out:
# array([[<AxesSubplot:title={'center':'id'}>,
#         <AxesSubplot:title={'center':'km4week'}>],
#        [<AxesSubplot:title={'center':'sp4week'}>,
#         <AxesSubplot:title={'center':'Wall21'}>],
#        [<AxesSubplot:title={'center':'MarathonTime'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data=data.drop(columns=['Name'])
data=data.drop(columns=['id'])
data=data.drop(columns=['Marathon'])
data=data.drop(columns=['CATEGORY'])
data
# Out:
#    Category  km4week    sp4week CrossTraining  Wall21  MarathonTime
# 0       MAM    132.8  14.434783           NaN    1.16          2.37
# 1       MAM     68.6  13.674419           NaN    1.23          2.59
# 2       MAM     82.7  13.520436           NaN    1.30          2.66
# 3       M45    137.5  12.258544           NaN    1.32          2.68
# 4       MAM     84.6  13.945055           NaN    1.36          2.74
# ..      ...      ...        ...           ...     ...           ...
# 82      M55     50.0  10.830325           NaN    2.02          3.93
# 83      M40     33.6  10.130653   ciclista 3h    1.94          3.93
# 84      M40     55.4  11.043189           NaN    1.94          3.94
# 85      M45     33.2  11.066667           NaN    2.05          3.95
# 86      M40     17.9  10.848485   ciclista 5h    2.05          3.98
#
# [87 rows x 6 columns]

# %%
data.isna().sum()
# Out:
# Category          6
# km4week           0
# sp4week           0
# CrossTraining    74
# Wall21            6
# MarathonTime      0
# dtype: int64

# %%
data['CrossTraining']=data['CrossTraining'].fillna(0)
data
# Out:
#    Category  km4week    sp4week CrossTraining  Wall21  MarathonTime
# 0       MAM    132.8  14.434783             0    1.16          2.37
# 1       MAM     68.6  13.674419             0    1.23          2.59
# 2       MAM     82.7  13.520436             0    1.30          2.66
# 3       M45    137.5  12.258544             0    1.32          2.68
# 4       MAM     84.6  13.945055             0    1.36          2.74
# ..      ...      ...        ...           ...     ...           ...
# 82      M55     50.0  10.830325             0    2.02          3.93
# 83      M40     33.6  10.130653   ciclista 3h    1.94          3.93
# 84      M40     55.4  11.043189             0    1.94          3.94
# 85      M45     33.2  11.066667             0    2.05          3.95
# 86      M40     17.9  10.848485   ciclista 5h    2.05          3.98
#
# [87 rows x 6 columns]

# %%
data.isna().sum()
# Out:
# Category         6
# km4week          0
# sp4week          0
# CrossTraining    0
# Wall21           6
# MarathonTime     0
# dtype: int64

# %%
data=data.dropna(how='any')
data
# Out:
#    Category  km4week    sp4week CrossTraining  Wall21  MarathonTime
# 0       MAM    132.8  14.434783             0    1.16          2.37
# 1       MAM     68.6  13.674419             0    1.23          2.59
# 2       MAM     82.7  13.520436             0    1.30          2.66
# 3       M45    137.5  12.258544             0    1.32          2.68
# 4       MAM     84.6  13.945055             0    1.36          2.74
# ..      ...      ...        ...           ...     ...           ...
# 82      M55     50.0  10.830325             0    2.02          3.93
# 83      M40     33.6  10.130653   ciclista 3h    1.94          3.93
# 84      M40     55.4  11.043189             0    1.94          3.94
# 85      M45     33.2  11.066667             0    2.05          3.95
# 86      M40     17.9  10.848485   ciclista 5h    2.05          3.98
#
# [81 rows x 6 columns]

# %%
data['CrossTraining'].unique()
# Out:
# array([0, 'ciclista 1h', 'ciclista 4h', 'ciclista 13h', 'ciclista 3h',
#        'ciclista 5h'], dtype=object)

# %%
val_cross= {"CrossTraining": {'ciclista 1h':1,'ciclista 4h':3,'ciclista 13h':5,'ciclista 3h':2,'ciclista 5h':4}}
data.replace(val_cross, inplace= True )
data
# Out:
# C:\Users\edizo\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#    Category  km4week    sp4week  CrossTraining  Wall21  MarathonTime
# 0       MAM    132.8  14.434783              0    1.16          2.37
# 1       MAM     68.6  13.674419              0    1.23          2.59
# 2       MAM     82.7  13.520436              0    1.30          2.66
# 3       M45    137.5  12.258544              0    1.32          2.68
# 4       MAM     84.6  13.945055              0    1.36          2.74
# ..      ...      ...        ...            ...     ...           ...
# 82      M55     50.0  10.830325              0    2.02          3.93
# ...

# %%
data['Category'].unique()
# Out:
# array(['MAM', 'M45', 'M40', 'M50', 'M55', 'WAM'], dtype=object)

# %%
val_cat= {"Category": {'MAM':1,'M40':2,'M45':3,'M50':4,'M55':5,'WAM':6}}
data.replace(val_cat, inplace= True )
data
# Out:
# C:\Users\edizo\anaconda3\lib\site-packages\pandas\core\indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)
#     Category  km4week    sp4week  CrossTraining  Wall21  MarathonTime
# 0          1    132.8  14.434783              0    1.16          2.37
# 1          1     68.6  13.674419              0    1.23          2.59
# 2          1     82.7  13.520436              0    1.30          2.66
# 3          3    137.5  12.258544              0    1.32          2.68
# 4          1     84.6  13.945055              0    1.36          2.74
# ..       ...      ...        ...            ...     ...           ...
# 82         5     50.0  10.830325              0    2.02          3.93
# ...

# %%
import matplotlib.pyplot as plt
plt.scatter(x=data['km4week'], y=data['MarathonTime'])
plt.title('km4week vs MarathonTime')
plt.xlabel('km4week')
plt.ylabel('MarathonTime')
plt.show()

# %%
plt.scatter(x=data['sp4week'], y=data['MarathonTime'])
plt.title('sp4week vs MarathonTime')
plt.xlabel('sp4week')
plt.ylabel('MarathonTime')
plt.show()

# %%
data=data.query('sp4week<1000')
plt.scatter(x=data['sp4week'], y=data['MarathonTime'])
plt.title('sp4week vs MarathonTime')
plt.xlabel('sp4week')
plt.ylabel('MarathonTime')
plt.show()

# %%
data_entrenamiento=data.sample(frac=0.8, random_state=0)
data_test=data.drop(data_entrenamiento.index)

# %%
data_entrenamiento
# Out:
#     Category  km4week    sp4week  CrossTraining  Wall21  MarathonTime
# 54         2     70.7  11.783333              0    1.77          3.47
# 28         3     51.6  13.008403              0    1.50          3.15
# 31         1     79.4  13.344538              0    1.60          3.19
# 84         2     55.4  11.043189              0    1.94          3.94
# 47         3     39.6  12.247423              0    1.67          3.35
# ..       ...      ...        ...            ...     ...           ...
# 55         1     26.9  13.121951              0    1.67          3.50
# 20         1     94.5  11.886792              0    1.45          2.99
# 79         1     53.9  11.802920              0    1.98          3.90
# 8          1     70.0  13.770492              1    1.38          2.83
# 13         2     84.4  13.836066              0    1.41          2.88
#
# [64 rows x 6 columns]

# %%
etiqueta_entrenamiento=data_entrenamiento.pop('MarathonTime')
etiqueta_test=data_test.pop('MarathonTime')

# %%
etiqueta_entrenamiento
# Out:
# 54    3.47
# 28    3.15
# 31    3.19
# 84    3.94
# 47    3.35
#       ...
# 55    3.50
# 20    2.99
# 79    3.90
# 8     2.83
# 13    2.88
# Name: MarathonTime, Length: 64, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
modelo=LinearRegression()
modelo.fit(data_entrenamiento,etiqueta_entrenamiento)
# Out:
# LinearRegression()

# %%
predicciones=modelo.predict(data_test)
predicciones
# Out:
# array([2.79362631, 2.81567434, 3.05744708, 3.04909907, 3.06029112,
#        3.29379815, 3.36147158, 3.36133523, 3.17442121, 3.29162736,
#        3.37726241, 3.5218461 , 3.59210252, 3.54963432, 3.66434731,
#        3.85281274])

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
error=np.sqrt(mean_squared_error(etiqueta_test,predicciones))
print("Error porcentual :%f" % (error*100))
# Out:
# Error porcentual :11.032473

# %%
nuevo_corredor= pd.DataFrame(np.array([[1,400,15,0,1.4]]),columns=['Category','km4week','sp4week','CrossTraining','Wall21'])

# %%
nuevo_corredor
# Out:
#    Category  km4week  sp4week  CrossTraining  Wall21
# 0       1.0    400.0     15.0            0.0     1.4
